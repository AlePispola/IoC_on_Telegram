# %%
# ============================================================
# MongoDB connection using PyMongo - User: DPA_Project_ReadOnly
# ============================================================


from pymongo import MongoClient
from pprint import pprint

# Connection string
uri = "mongodb://DPA_Project_ReadOnly:DPA_sd_2025@130.192.238.49:27015/?authSource=admin"

# Create the MongoDB client
client = MongoClient(uri)

# Check the connection
try:
    server_info = client.server_info()
    print("Connection successful")
    pprint(server_info)
except Exception as e:
    print("Connection error:")
    print(e)

# List available databases
print("\nAvailable databases:")
for db_name in client.list_database_names():
    print(" -", db_name)

# Select a database
db = client["GroupMonitoringRelease"]  # you can replace it with "GroupMonitoringRelease"

# List collections in the selected database
collection_names = db.list_collection_names()
print("\nCollections in USelection2024:")
print(collection_names)

# Read sample documents from the first collection, if any
if collection_names:
    coll = db[collection_names[0]]
    print(f"\nFirst 5 documents in collection '{collection_names[0]}':")
    for doc in coll.find().limit(5):
        pprint(doc)
else:
    print("No collections found in the selected database.")

# Close the connection
client.close()
print("\nConnection closed.")
# Out:
# Connection successful
# {'allocator': 'tcmalloc',
#  'bits': 64,
#  'buildEnvironment': {'cc': '/opt/mongodbtoolchain/v3/bin/gcc: gcc (GCC) 8.5.0',
#                       'ccflags': '-Werror -include mongo/platform/basic.h '
#                                  '-ffp-contract=off '
#                                  '-fasynchronous-unwind-tables -ggdb -Wall '
#                                  '-Wsign-compare -Wno-unknown-pragmas '
#                                  '-Winvalid-pch -fno-omit-frame-pointer '
#                                  '-fno-strict-aliasing -O2 -march=sandybridge '
#                                  '-mtune=generic -mprefer-vector-width=128 '
#                                  '-Wno-unused-local-typedefs '
#                                  '-Wno-unused-function '
#                                  '-Wno-deprecated-declarations '
#                                  '-Wno-unused-const-variable '
#                                  '-Wno-unused-but-set-variable '
# ...
